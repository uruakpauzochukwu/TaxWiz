# %%
import os
import sys
# Find the absolute path of the project root (one level above `notebooks/`)
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import pickle
from utils.utils import chunk_text, create_index, upsert_chunks_to_pinecone

# %%
class Chunk:
    def __init__(self, text, metadata):
        self.text = text
        self.metadata = metadata

# %%
# 1.3 Read it back
with open("chunks_dict.pkl", "rb") as f:
    extracted_text = pickle.load(f)

# %%
all_chunks = []
for k, v in extracted_text.items():
    all_chunks+=chunk_text(text=v, chunk_size=1050, overlap=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 all_chunks = []
# ----> 2 for k, v in extracted_text.items():
#       3     all_chunks+=chunk_text(text=v, chunk_size=1050, overlap=50)
#
# AttributeError: 'list' object has no attribute 'items'

# %%
index = 'taxwiz'
create_index(index)
# Out:
# Index 'taxwiz' already exists.

# %%
upsert_chunks_to_pinecone(text_chunks=all_chunks, namespace='wiztax')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 upsert_chunks_to_pinecone(text_chunks=all_chunks, namespace='wiztax')
#
# NameError: name 'all_chunks' is not defined
